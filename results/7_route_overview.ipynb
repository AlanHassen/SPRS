# %%
import pandas as pd
from multiretro.routeplanning.logic.evaluation.route_evaluation import *

import os

config_path = "/multiretro/resources/multiretro_settings.yaml"
os.environ["MULTIRETRO_SETTINGS_PATH"] = str(config_path)

# %%
selected_molecule = 11

# %%
from IPython.display import display

def load_hdf(hdf_path):
    df = pd.read_hdf(hdf_path, key='table')
    results = AiZynthfinderResults(df[:20])
    return results

def visualize_route(results, selected_molecule):
    molecule = results.get_molecules()[selected_molecule]
    #molecule.remove_unsolved_routes()
    routes = molecule.get_synthesis_routes()
    #for route in routes:
    #    display(route.visualize_route())
    display(routes[0].visualize_route())
    #route_images = []
    #for route in routes:
        #route_images.append(route.visualize_route())

   # return route_images


# custom display function that resizes the images
def display_images(images):
    display(images[0])
    for image in images:
        display(image)
        #width = 600
        #height = 300
        #display(image.resize((width, height)))

# %% [markdown]
# # Retro* Full Stock

# %%
full_building_blocks = "/Users/alankaihassen/Development/diversity_mcts/repository/data/results/azf/full_building_blocks/"

retrostar_best_route = full_building_blocks + "0_dpvn_ssm_chembl_retrostar_0_policy_uspto_template_based_stock_emolecules_depth_30_25000_iterations.hdf"
print("RetroStar Best Route")
retrostar_best_route = load_hdf(retrostar_best_route)
retrostar_best_route.aizynthfinder_results
# Out:
# RetroStar Best Route
# 2025-03-20 11:38:13.756 | INFO     | multiretro.utils.config:load_config:18 - Loading configuration from /multiretro/resources/multiretro_settings.yaml
# /multiretro/src/multiretro/routeplanning/logic/evaluation/route_evaluation.py:709: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.aizynthfinder_results["molecule_results"] = molecule_results
#     index                                             target  search_time  \
# 0       0  CCN1CCN(Cc2ccc(NC(=O)c3ccc(C)c(C#Cc4coc5ccccc4...     4.176107
# 1       1  CCNC(=O)c1ccc2c(c1)NC(=O)C2=C(Nc1ccc(N(CCN(C)C...     2.061671
# 2       2  COc1cc(N2CCN(C)CC2)ccc1Nc1ncc(Cl)c(Oc2cccc(NC(...     3.429387
# ...

# %%
visualize_route(retrostar_best_route, selected_molecule)
# Out:
# <PIL.Image.Image image mode=RGB size=993x751>

# %% [markdown]
# # Retro* No Best First Stock

# %%
removed_bb_path = "/Users/alankaihassen/Development/diversity_mcts/repository/data/results/azf/removed_best_first_building_blocks/"

# %%
retro_star_no_best_first = removed_bb_path + "0_dpvn_ssm_chembl_retrostar_0_policy_uspto_template_based_stock_emolecules_without_retrostar_depth_30_25000_iterations.hdf"

print("RetroStar No Best First Route")

results = load_hdf(retro_star_no_best_first)
#results.aizynthfinder_results

visualize_route(results, selected_molecule)
# Out:
# RetroStar No Best First Route
# /multiretro/routeplanning/logic/evaluation/route_evaluation.py:709: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.aizynthfinder_results["molecule_results"] = molecule_results
# <PIL.Image.Image image mode=RGB size=1002x735>

# %%
DEFAULT_mcts_no_best_first = removed_bb_path + "1_dpvn_ssm_chembl_DEFAULT_mcts_50_wide_policy_uspto_template_based_stock_emolecules_without_retrostar_depth_30.hdf"

print("MCTS No Best First Route")

results = load_hdf(DEFAULT_mcts_no_best_first)
#results.aizynthfinder_results

visualize_route(results, selected_molecule)
# Out:
# MCTS No Best First Route
# /multiretro/routeplanning/logic/evaluation/route_evaluation.py:709: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.aizynthfinder_results["molecule_results"] = molecule_results
# <PIL.Image.Image image mode=RGB size=1365x587>

# %%
distance_mcts_no_best_first = removed_bb_path + f"2_dpvn_ssm_chembl_mcts_diversity_forcing_policy_uspto_template_based_stock_emolecules_without_retrostar_0_depth_30.hdf"

print("Distance-MCTS No Best First Route")

results = load_hdf(distance_mcts_no_best_first)
#results.aizynthfinder_results

visualize_route(results, selected_molecule)
# Out:
# Distance-MCTS No Best First Route
# /multiretro/routeplanning/logic/evaluation/route_evaluation.py:709: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.aizynthfinder_results["molecule_results"] = molecule_results
# <PIL.Image.Image image mode=RGB size=1432x791>

# %%
cluster_retrostar_no_best_first = removed_bb_path + f"5_dpvn_ssm_chembl_retrostar_0_clustered_first_occurence_policy_uspto_template_based_stock_emolecules_without_retrostar_0_depth_30_25000_iterations.hdf"

print("Cluster-Retro* No Best First Route")

results = load_hdf(cluster_retrostar_no_best_first)
#results.aizynthfinder_results

visualize_route(results, selected_molecule)
# Out:
# Cluster-Retro* No Best First Route
# /multiretro/routeplanning/logic/evaluation/route_evaluation.py:709: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.aizynthfinder_results["molecule_results"] = molecule_results
# <PIL.Image.Image image mode=RGB size=1228x751>

# %%
cluster_mcts_no_best_first = removed_bb_path + f"6_dpvn_ssm_chembl_expansion_cluster_mcts_first_occurence_policy_uspto_template_based_stock_emolecules_without_retrostar_0_depth_30.hdf"

print("Cluster-MCTS No Best First Route")

results = load_hdf(cluster_mcts_no_best_first)
#results.aizynthfinder_results

visualize_route(results, selected_molecule)
# Out:
# Cluster-MCTS No Best First Route
# /multiretro/routeplanning/logic/evaluation/route_evaluation.py:709: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.aizynthfinder_results["molecule_results"] = molecule_results
# <PIL.Image.Image image mode=RGB size=1228x751>
